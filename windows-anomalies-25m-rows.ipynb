# %%
# Cell 1: Setup & Installation
# !pip install "pandas<2.0.0"
# !pip install drain3 torch transformers scikit-learn
# Out:
# Requirement already satisfied: pandas<2.0.0 in /usr/local/lib/python3.11/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0.0) (2025.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0.0) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->pandas<2.0.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->pandas<2.0.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->pandas<2.0.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->pandas<2.0.0) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->pandas<2.0.0) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->pandas<2.0.0) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.0->pandas<2.0.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.0->pandas<2.0.0) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.0->pandas<2.0.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.0->pandas<2.0.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.0->pandas<2.0.0) (2024.2.0)
# Requirement already satisfied: drain3 in /usr/local/lib/python3.11/dist-packages (0.9.11)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: jsonpickle==1.5.1 in /usr/local/lib/python3.11/dist-packages (from drain3) (1.5.1)
# Requirement already satisfied: cachetools==4.2.1 in /usr/local/lib/python3.11/dist-packages (from drain3) (4.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)

# %%
# Cell 2 (Re-run this cell first)
import pandas as pd
from drain3 import TemplateMiner
from drain3.template_miner_config import TemplateMinerConfig
import os

TOTAL_LINES_TO_PROCESS = 2500000 
log_file_path = '/kaggle/input/loghub-windows-dataset/Windows.log'

config = TemplateMinerConfig()
template_miner = TemplateMiner(config=config)
all_parsed_logs = []
line_count = 0

print(f"Starting parsing for a unified vocabulary (up to {TOTAL_LINES_TO_PROCESS} lines)...")
try:
    with open(log_file_path, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            if line_count >= TOTAL_LINES_TO_PROCESS: break
            log_message = line.strip()
            if not log_message: continue
            result = template_miner.add_log_message(log_message)
            line_count += 1
            all_parsed_logs.append({'EventId': f"E{result['cluster_id']}", 'OriginalLog': log_message})
            if line_count % 250000 == 0: print(f"Processed {line_count} lines...")
except FileNotFoundError:
    print(f"Error: The file was not found at {log_file_path}.")

print(f"\nLog parsing complete. Total lines: {len(all_parsed_logs)}")
df_full = pd.DataFrame(all_parsed_logs)

print("\n--- Parsed Log Data Sample ---")
print(df_full.head())
print(f"\nTotal unique log templates found: {len(template_miner.drain.clusters)}")
# Out:
# Starting parsing for a unified vocabulary (up to 2500000 lines)...
# Processed 250000 lines...
# Processed 500000 lines...
# Processed 750000 lines...
# Processed 1000000 lines...
# Processed 1250000 lines...
# Processed 1500000 lines...
# Processed 1750000 lines...
# Processed 2000000 lines...
# Processed 2250000 lines...
# Processed 2500000 lines...
#
# Log parsing complete. Total lines: 2500000
#
# --- Parsed Log Data Sample ---
#   EventId                                        OriginalLog
# 0      E1  ﻿2016-09-28 04:30:30, Info                  CB...
# 1      E2  2016-09-28 04:30:30, Info                  CBS...
# 2      E3  2016-09-28 04:30:31, Info                  CSI...
# 3      E3  2016-09-28 04:30:31, Info                  CSI...
# 4      E3  2016-09-28 04:30:31, Info                  CSI...
#
# Total unique log templates found: 479

# %%
# Cell 3 (Re-run this cell after Cell 2 finishes)
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from transformers import BertConfig, BertModel
from tqdm import tqdm
import pickle
from torch.amp import GradScaler, autocast

# ===================================================================
# 1. Data Preparation
# ===================================================================
event_ids = df_full['EventId'].unique()
vocab = {event_id: i for i, event_id in enumerate(event_ids)}
vocab['[MASK]'] = len(vocab)
vocab_size = len(vocab)
print(f"Unified vocabulary size: {vocab_size}")

train_val_df, test_df = train_test_split(df_full, test_size=0.1, random_state=42)
train_df, val_df = train_test_split(train_val_df, test_size=1/9, random_state=42)

print(f"Training set size: {len(train_df)} lines")
print(f"Validation set size: {len(val_df)} lines")
print(f"Test set size: {len(test_df)} lines")

class LogDataset(Dataset):
    def __init__(self, dataframe, vocab, seq_len=128):
        self.data = dataframe['EventId'].tolist()
        self.vocab = vocab
        self.seq_len = seq_len
    def __len__(self):
        return len(self.data) - self.seq_len + 1
    def __getitem__(self, idx):
        sequence_events = self.data[idx : idx + self.seq_len]
        sequence_indices = [self.vocab.get(event_id, 0) for event_id in sequence_events]
        return torch.tensor(sequence_indices, dtype=torch.long)

sequence_length = 128 
batch_size = 256
train_dataset = LogDataset(train_df, vocab, seq_len=sequence_length)
val_dataset = LogDataset(val_df, vocab, seq_len=sequence_length)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

# ===================================================================
# 2. Model Definition
# ===================================================================
class LogBERT(nn.Module):
    def __init__(self, vocab_size, hidden_size=256, num_layers=4, num_attention_heads=4, max_seq_len=128):
        super(LogBERT, self).__init__()
        config = BertConfig(vocab_size=vocab_size, hidden_size=hidden_size, num_hidden_layers=num_layers, num_attention_heads=num_attention_heads, max_position_embeddings=max_seq_len + 2)
        self.bert = BertModel(config)
        self.classifier = nn.Linear(hidden_size, vocab_size)
    def forward(self, input_ids):
        outputs = self.bert(input_ids=input_ids)
        return self.classifier(outputs.last_hidden_state)

# ===================================================================
# 3. Training Execution
# ===================================================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
model = LogBERT(vocab_size=vocab_size, max_seq_len=sequence_length).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()
scaler = GradScaler()
num_epochs, patience, best_val_loss, epochs_no_improve = 25, 3, float('inf'), 0
best_model_path = 'logbert_best_model_unified_vocab.pth'

for epoch in range(num_epochs):
    print(f"\n--- Epoch {epoch + 1}/{num_epochs} ---")
    model.train()
    total_train_loss = 0
    for sequence in tqdm(train_loader, desc="Training"):
        sequence, labels = sequence.to(device), sequence.clone().to(device)
        prob = 0.15 
        mask = torch.rand(sequence.shape, device=device) < prob
        sequence[mask] = vocab['[MASK]']
        labels[~mask] = -100  
        optimizer.zero_grad(set_to_none=True)
        with autocast(device_type=device.type, dtype=torch.float16):
            outputs = model(sequence)
            loss = criterion(outputs.view(-1, vocab_size), labels.view(-1))
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_train_loss += loss.item()
    print(f"Average Training Loss: {total_train_loss / len(train_loader):.4f}")

    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for sequence in tqdm(val_loader, desc="Validating"):
            sequence, labels = sequence.to(device), sequence.clone().to(device)
            prob = 0.15
            mask = torch.rand(sequence.shape, device=device) < prob
            sequence[mask] = vocab['[MASK]']
            labels[~mask] = -100
            with autocast(device_type=device.type, dtype=torch.float16):
                outputs = model(sequence)
                loss = criterion(outputs.view(-1, vocab_size), labels.view(-1))
            total_val_loss += loss.item()
    avg_val_loss = total_val_loss / len(val_loader)
    print(f"Validation Loss: {avg_val_loss:.4f}")

    if avg_val_loss < best_val_loss:
        best_val_loss, epochs_no_improve = avg_val_loss, 0
        torch.save(model.state_dict(), best_model_path)
        print(f"Validation loss improved. Saving best model to {best_model_path}")
    else:
        epochs_no_improve += 1
        print(f"No improvement in validation loss for {epochs_no_improve} epoch(s).")
    if epochs_no_improve >= patience:
        print(f"\nEarly stopping triggered after {epoch + 1} epochs.")
        break
print(f"\n--- Training Finished ---")

# ===================================================================
# 4. Save the Unified Vocabulary for Testing
# ===================================================================
with open('vocab_unified.pkl', 'wb') as f:
    pickle.dump(vocab, f)
print("Unified vocabulary saved to vocab_unified.pkl")
# Out:
# Unified vocabulary size: 480
# Training set size: 2000000 lines
# Validation set size: 250000 lines
# Test set size: 250000 lines
# Using device: cuda
#
# --- Epoch 1/25 ---
# Training:   2%|▏         | 141/7813 [00:21<17:57,  7.12it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# Training: 100%|██████████| 7813/7813 [22:30<00:00,  5.78it/s]
# Average Training Loss: 1.8665
# Validating: 100%|██████████| 977/977 [00:59<00:00, 16.44it/s]
# Validation Loss: 1.8583
# Validation loss improved. Saving best model to logbert_best_model_unified_vocab.pth
#
# --- Epoch 2/25 ---
# Training: 100%|██████████| 7813/7813 [22:35<00:00,  5.76it/s]
# Average Training Loss: 1.8584
# Validating: 100%|██████████| 977/977 [00:59<00:00, 16.46it/s]
# Validation Loss: 1.8585
# No improvement in validation loss for 1 epoch(s).
#
# --- Epoch 3/25 ---
# Training: 100%|██████████| 7813/7813 [22:20<00:00,  5.83it/s]
# Average Training Loss: 1.8576
# Validating: 100%|██████████| 977/977 [00:58<00:00, 16.63it/s]
# Validation Loss: 1.8580
# Validation loss improved. Saving best model to logbert_best_model_unified_vocab.pth
#
# --- Epoch 4/25 ---
# Training: 100%|██████████| 7813/7813 [22:22<00:00,  5.82it/s]
# Average Training Loss: 1.8574
# Validating: 100%|██████████| 977/977 [00:58<00:00, 16.76it/s]
# Validation Loss: 1.8588
# No improvement in validation loss for 1 epoch(s).
#
# --- Epoch 5/25 ---
# Training: 100%|██████████| 7813/7813 [22:11<00:00,  5.87it/s]
# Average Training Loss: 1.8578
# Validating: 100%|██████████| 977/977 [00:57<00:00, 16.92it/s]
# Validation Loss: 1.8581
# No improvement in validation loss for 2 epoch(s).
#
# --- Epoch 6/25 ---
# Training: 100%|██████████| 7813/7813 [22:06<00:00,  5.89it/s]
# Average Training Loss: 1.8578
# Validating: 100%|██████████| 977/977 [00:57<00:00, 16.85it/s]
# Validation Loss: 1.8579
# Validation loss improved. Saving best model to logbert_best_model_unified_vocab.pth
#
# --- Epoch 7/25 ---
# Training: 100%|██████████| 7813/7813 [22:00<00:00,  5.92it/s]
# Average Training Loss: 1.8575
# Validating: 100%|██████████| 977/977 [00:57<00:00, 16.88it/s]
# Validation Loss: 1.8582
# No improvement in validation loss for 1 epoch(s).
#
# --- Epoch 8/25 ---
# Training: 100%|██████████| 7813/7813 [22:03<00:00,  5.90it/s]
# Average Training Loss: 1.8576
# Validating: 100%|██████████| 977/977 [00:58<00:00, 16.70it/s]
# Validation Loss: 1.8584
# No improvement in validation loss for 2 epoch(s).
#
# --- Epoch 9/25 ---
# Training: 100%|██████████| 7813/7813 [22:14<00:00,  5.85it/s]
# Average Training Loss: 1.8577
# Validating: 100%|██████████| 977/977 [00:59<00:00, 16.49it/s]
# Validation Loss: 1.8583
# No improvement in validation loss for 3 epoch(s).
#
# Early stopping triggered after 9 epochs.
#
# --- Training Finished ---
# Unified vocabulary saved to vocab_unified.pkl

# %%
# Cell 4: Testing the Model on the Held-Out Test Set
import torch, torch.nn as nn
from transformers import BertConfig, BertModel
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import pickle
import pandas as pd

# ===================================================================
# 1. Setup and Load the Saved Model and UNIFIED Vocabulary
# ===================================================================
# Model definition must be available
class LogBERT(nn.Module):
    def __init__(self, vocab_size, hidden_size=256, num_layers=4, num_attention_heads=4, max_seq_len=128):
        super(LogBERT, self).__init__()
        config = BertConfig(vocab_size=vocab_size, hidden_size=hidden_size, num_hidden_layers=num_layers, num_attention_heads=num_attention_heads, max_position_embeddings=max_seq_len + 2)
        self.bert = BertModel(config)
        self.classifier = nn.Linear(hidden_size, vocab_size)
    def forward(self, input_ids):
        outputs = self.bert(input_ids=input_ids)
        return self.classifier(outputs.last_hidden_state)

# Load the UNIFIED vocabulary
with open('vocab_unified.pkl', 'rb') as f:
    vocab = pickle.load(f)
vocab_size = len(vocab)
sequence_length = 128
print("Unified vocabulary loaded successfully.")

# Initialize model and load the best weights from the new training run
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LogBERT(vocab_size=vocab_size, max_seq_len=sequence_length).to(device)
model.load_state_dict(torch.load('logbert_best_model_unified_vocab.pth'))
model.eval()
print("Best model (trained on unified vocab) loaded successfully.")

# ===================================================================
# 2. Prepare the Test Data (using the test_df from Cell 3)
# ===================================================================
class TestLogDataset(Dataset):
    def __init__(self, dataframe, vocab, seq_len=128):
        self.df = dataframe
        self.vocab = vocab
        self.seq_len = seq_len
    def __len__(self):
        return len(self.df) - self.seq_len + 1
    def __getitem__(self, idx):
        sequence_events = self.df['EventId'].iloc[idx:idx+self.seq_len].tolist()
        original_logs = self.df['OriginalLog'].iloc[idx:idx+self.seq_len].tolist()
        sequence_indices = [self.vocab.get(event_id, 0) for event_id in sequence_events]
        return torch.tensor(sequence_indices, dtype=torch.long), original_logs

def collate_fn(batch):
    sequences, original_logs = zip(*batch)
    return torch.stack(sequences, dim=0), list(original_logs)

test_dataset = TestLogDataset(test_df, vocab, seq_len=sequence_length)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False, collate_fn=collate_fn)

# ===================================================================
# 3. Anomaly Detection on the Test Set
# ===================================================================
print("\nStarting anomaly detection on the held-out test set...")
anomalous_sequences = []
G, R = 9, 3 

with torch.no_grad():
    for sequences, original_logs_batch in tqdm(test_loader, desc="Detecting Anomalies"):
        sequences = sequences.to(device)
        predictions = model(sequences)
        top_g_predictions = torch.topk(predictions, G, dim=2).indices
        
        for i in range(sequences.shape[0]):
            mismatch_count = 0
            for j in range(sequences.shape[1]):
                if sequences[i, j].item() not in top_g_predictions[i, j]:
                    mismatch_count += 1
            if mismatch_count > R:
                anomalous_sequences.append({"mismatches": mismatch_count, "sequence": original_logs_batch[i]})

print(f"\n--- Detection Complete ---")
print(f"Total sequences tested: {len(test_dataset)}")
print(f"Anomalous sequences found: {len(anomalous_sequences)}")

# Print the first 5 detected anomalies
for i, anomaly in enumerate(anomalous_sequences[:5]):
    print(f"\n--- Anomaly #{i+1} (Mismatches: {anomaly['mismatches']}) ---")
    for log_line in anomaly['sequence']:
        print(log_line)
# Out:
# Unified vocabulary loaded successfully.
# Best model (trained on unified vocab) loaded successfully.
#
# Starting anomaly detection on the held-out test set...
# Detecting Anomalies: 100%|██████████| 977/977 [36:10<00:00,  2.22s/it]
# --- Detection Complete ---
# Total sequences tested: 249873
# Anomalous sequences found: 247219
#
# --- Anomaly #1 (Mismatches: 6) ---
# 2016-10-17 03:20:05, Info                  CBS    Appl: detect Parent, Package: Package_for_KB2758857_RTM~31bf3856ad364e35~amd64~~6.1.1.0, Parent: Microsoft-Windows-WinPE-LanguagePack-Package~31bf3856ad364e35~amd64~sv-SE~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:22:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_es-es_066bc2669749f638 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:04, Info                  CBS    Appl: detect Parent, Package: Package_208_for_KB2871997~31bf3856ad364e35~amd64~~6.1.2.5, Parent: Microsoft-Windows-EmbeddedFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~ar-SA~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:11:07, Info                  CBS    Appl: detect Parent, Package: Package_310_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, disposition state from detectParent: Absent
# 2016-10-17 03:11:03, Info                  CBS    Appl: detectParent: package: Package_236_for_KB3185278~31bf3856ad364e35~amd64~~6.1.1.4, related parent found: Microsoft-Windows-Foundation-Package~31bf3856ad364e35~amd64~~6.1.7600.16385, which is not real parent
# 2016-10-25 14:32:32, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-rpc-http_31bf3856ad364e35_0.0.0.0_none_c3d2e29d877e25e4 (6.1.7601.23338), elevation:2, lower version revision holder: 6.1.7601.17514
# 2016-10-17 03:15:17, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_da-dk_d7c32e6bb15242a4 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:52, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_ko-kr_a70500536621343a (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:46, Info                  CBS    Appl: detectParent: package: Package_119_for_KB3149090~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:20:16, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.23099_ar-sa_553adf470800bdac, elevation: 2, applicable: 0
# 2016-10-17 03:22:39, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_da-dk_3e9b7ce6afa80640 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:11:58, Info                  CBS    Exec: Staging Package: Package_63_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, Update: 3185330-122_neutral_LDR, PinDeployment: amd64_3bbd1d14761b629a5a8eed69e8d2434d_31bf3856ad364e35_6.1.7601.23542_none_4abe724d23ed6a6e
# 2016-10-11 03:10:16, Info                  CBS    EvaluateApplicability, package: Package_104_for_KB982018~31bf3856ad364e35~amd64~~6.1.3.2, Package applicability: Superseded.
# 2016-10-11 03:09:59, Info                  CBS    Appl: detectParent: package: Package_13_for_KB2773072~31bf3856ad364e35~amd64~~6.1.1.5, no parent found, go absent
# 2016-10-25 14:34:32, Info                  CBS    Appl: detect Parent, Package: Package_37_for_KB3023215~31bf3856ad364e35~amd64~~6.1.1.0, Parent: WinEmb-NetFx20~31bf3856ad364e35~amd64~he-IL~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:17:13, Info                  CBS    Appl: SelfUpdate detect, component: x86_system.web_b03f5f7f11d50a3a_6.1.7601.22617_none_b4b61ec9eccec6ac, elevation: 4, applicable: 1
# 2016-10-17 03:13:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_hu-hu_f093b8ad6e7bdbb6 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:05:43, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_zh-cn_6626cff07e44dea5 (6.1.7601.23136), elevation:2, lower version revision holder: 6.1.7601.19160
# 2016-10-11 03:02:53, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_cs-cz_4543013c0104990b (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23142_es-es_66f9131f1775c651, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:16:07, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_0.0.0.0_es-es_f3859f26872cf297 (6.1.7601.23121), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:17:57, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_cs-cz_9174900bcf701166 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:02:38, Info                  CBS    Appl: detect Parent, Package: Package_21_for_KB3127220~31bf3856ad364e35~amd64~~6.1.1.0, Parent: Microsoft-Windows-NetFx2-ServerCore-OC-Package~31bf3856ad364e35~amd64~pt-PT~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:03:39, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_he-il_6f3bc71cc166fe5e (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:10:25, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22712_zh-tw_c0173cf7b5d0ba3e, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:26, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_tr-tr_68278194914e1c2c (6.1.7601.22712), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:44, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23136_fi-fi_fb6935e8c68baf80, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:11:08, Info                  CBS    Appl: detectParent: package: Package_468_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-25 14:32:27, Info                  CBS    Appl: detectParent: package: Package_260_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:02:54, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_pt-pt_f90f512750aef15a (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:55, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22322_pt-br_d2472dcf9e643682, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:31, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-advapi32.resources_31bf3856ad364e35_0.0.0.0_he-il_7f2483e98ac4a5f8 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:15, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23017_nl-nl_15a563f25a41ac06, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:34:26, Info                  CBS    Appl: Evaluating package applicability for package Package_112_for_KB2726535~31bf3856ad364e35~amd64~~6.1.1.1, applicable state: Absent
# 2016-10-11 03:08:13, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_nl-nl_930a2682e36c1040 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:45, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23136_pt-br_5e1f0adc3dfec950, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:46, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-security-ntlm_31bf3856ad364e35_0.0.0.0_none_fcab7e0463127084 (6.1.7601.22807), elevation:2, lower version revision holder: 6.1.7601.19160
# 2016-10-17 03:19:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_es-es_5c35b0cbd1848155, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:17:04, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22099_ja-jp_13d61ea883db0984, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:04:01, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_tr-tr_0c08e610d8f0aaf6 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_tr-tr_68278194914e1c2c (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:17:42, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-cryptbase_31bf3856ad364e35_6.1.7601.23154_none_c3ea00f4ddd7d283, elevate: 16, applicable(true/false): 1
# 2016-10-17 03:21:09, Info                  CBS    Appl: detect Parent, Package: Package_54_for_KB3181988~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-Common-Drivers-Package~31bf3856ad364e35~amd64~cs-CZ~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:09:53, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_es-es_d496384bb6915f69 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:13:09, Info                  CBS    Appl: detectParent: package: Package_7_for_KB2656356~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-25 14:32:47, Info                  CBS    Appl: detectParent: package: Package_5_for_KB2943357~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-17 03:04:14, Info                  CBS    Appl: detectParent: package: Package_for_KB3192391~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-11 03:10:01, Info                  CBS    Appl: Evaluating package applicability for package Package_for_KB2685813~31bf3856ad364e35~amd64~~6.1.1.11, applicable state: Installed
# 2016-10-17 03:15:19, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-csrsrv_31bf3856ad364e35_6.1.7601.23338_none_3279b1a0098866da, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:34:17, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.22472_zh-hk_481aa1f4b4f685e6, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:33, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_el-gr_f636a2d0e4c2e0a8 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:54, Info                  CBS    Appl: detect Parent, Package: Package_55_for_KB2894844~31bf3856ad364e35~amd64~~6.1.1.1, disposition state from detectParent: Absent
# 2016-10-11 03:10:21, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_zh-tw_ec1bf45bcc91abeb (6.1.7601.22923), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-11 03:09:15, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_de-de_310d5f2b6b860874 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_0.0.0.0_nl-nl_55817b43b9b8f3c9 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_0.0.0.0_de-de_f384b3ec41d2ebfd (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_el-gr_e45d3fb5a093c368 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:59, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-pt_8b175288542262e4 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:13, Info                  CBS    Appl: Package: Package_26_for_KB2972100~31bf3856ad364e35~amd64~~6.1.1.0, Update: 2972100-55_neutral_LDR, Applicable: NotApplicable, Disposition: Staged
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_cs-cz_a1619cbfb9620a41 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_6.1.7601.23142_pt-pt_d7a3baca7ffed09d, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:26, Info                  CBS    Appl: Evaluating applicability block(non detectUpdate part), disposition is: Staged, applicability: Applicable, result applicability state: Installed
# 2016-10-17 03:21:54, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_0.0.0.0_tr-tr_dc48bb2ff1b829fe (6.1.7601.22322), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:15, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.23109_pl-pl_e9841fd93ae4b2f5, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:01, Info                  CBS    Appl: detectParent: package: Package_for_KB2772930~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_8a35831c54b2f308 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-advapi32.resources_31bf3856ad364e35_6.1.7601.23338_pl-pl_1a50f8d8966beb32, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:01, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_6.1.7601.22252_hu-hu_bc3747d28db6b6cf, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_e40033fc0e86d05a (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:31, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_ar-sa_7200c202d2207ab3 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:40, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22865_zh-tw_ca9de316fbeee185, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:23, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_0.0.0.0_et-ee_a8e1b58fe9608558 (6.1.7601.22269), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:26, Info                  CBS    Appl: detectParent: package: Package_80_for_KB2574819~31bf3856ad364e35~amd64~~6.1.2.0, no parent found, go absent
# 2016-10-25 14:32:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-wow64_31bf3856ad364e35_6.1.7601.23338_none_d11842a43b79f6da, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:27, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_fr-fr_99141e19d7848be6 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:10:32, Info                  CBS    Appl: detectParent: package: Package_245_for_KB3185278~31bf3856ad364e35~amd64~~6.1.1.4, no parent found, go absent
# 2016-10-25 14:33:11, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_de-de_2bda056ec78c61ff (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:18, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_pt-pt_c5db2d233bc229c4, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:19:42, Info                  CBS    Appl: detectParent: package: Package_for_KB3042058_RTM~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22814_nl-nl_15a2890c5a442f98, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-smbminirdr_31bf3856ad364e35_6.1.7601.23126_none_de38090980e1294c, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:21, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_de-de_3bc71222b17e5ada (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:13:37, Info                  CBS    EvaluateApplicability, package: Package_113_for_KB3146706~31bf3856ad364e35~amd64~~6.1.1.2, Package applicability: Absent.
# 2016-10-17 03:22:17, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22321_el-gr_2c6dea1eea45ed8b, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:04:02, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-kernelbase_31bf3856ad364e35_6.1.7601.23338_none_8ff4f2ee18bed5ab, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:10, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-r..nt-v1-api.resources_31bf3856ad364e35_0.0.0.0_nb-no_68f456162a7fb4d1 (6.1.7601.22530), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_zh-cn_443e5289877e40b1 (6.1.7601.22865), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-11 03:10:21, Info                  CBS    Appl: detect Parent, Package: Package_177_for_KB3004375~31bf3856ad364e35~amd64~~6.1.3.1, Parent: WinEmb-BootEnv~31bf3856ad364e35~amd64~zh-TW~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:47, Info                  CBS    Appl: detect Parent, Package: Package_30_for_KB2984972~31bf3856ad364e35~amd64~~6.1.1.4, Parent: Microsoft-Windows-CredentialManagementRole~31bf3856ad364e35~amd64~zh-CN~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:55, Info                  CBS    EvaluateApplicability, package: Package_80_for_KB2773072~31bf3856ad364e35~amd64~~6.1.1.5, Package applicability: Absent.
# 2016-10-11 03:04:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_el-gr_c3027ecccfd61912, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.23126_tr-tr_41a2327b1c908274, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:23, Info                  CBS    Appl: detectParent: package: Package_111_for_KB3192391~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-11 03:10:06, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_cs-cz_9174900bcf701166 (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:18, Info                  CBS    Appl: detectParent: package: Package_42_for_KB3149090~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:03:50, Info                  CBS    Appl: detect Parent, Package: Package_72_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~it-IT~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:16, Info                  CBS    Appl: detectParent: package: Package_124_for_KB3072630~31bf3856ad364e35~amd64~~6.1.1.0, no parent found, go absent
# 2016-10-11 03:03:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_nb-no_c16d0ba31efef6c5 (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:06:39, Info                  CBS    Appl: detect Parent, Package: Package_129_for_KB3080079~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~cs-CZ~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-25 14:34:29, Info                  CBS    Appl: Selfupdate, Component: amd64_netfx-system.directoryservices.protocols_b03f5f7f11d50a3a_6.1.0.0_none_fb39d4586f220888 (6.1.7601.18923), elevation:16, lower version revision holder: 6.1.7601.18523
# 2016-10-11 03:02:55, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_fr-fr_7c8108074d5d1c40 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-advapi32.resources_31bf3856ad364e35_0.0.0.0_de-de_937297e80a212008 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:01, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_0.0.0.0_pt-br_f55678c6f3b9fe91 (6.1.7601.22252), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_tr-tr_62f427d7ed5475b7 (6.1.7601.22653), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:26, Info                  CBS    Appl: detectParent: package: Package_157_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:08:59, Info                  CBS    Appl: detectParent: package: Package_58_for_KB3133977~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-11 03:09:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-p..talcontrolssettings_31bf3856ad364e35_6.1.7601.22183_none_524f42ae3f666125, elevate: 16, applicable(true/false): 1
# 2016-10-11 03:10:10, Info                  CBS    Appl: detectParent: package: Package_51_for_KB3102429~31bf3856ad364e35~amd64~~6.1.2.0, no parent found, go absent
# 2016-10-11 03:03:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_hu-hu_c3f1884f31bceb5c (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:13:28, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-msauditevtlog_31bf3856ad364e35_6.1.7601.23126_none_25e91622a8312ee5, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22814_cs-cz_23f9ff49303a2999, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:34:17, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_0.0.0.0_es-es_0b4085839db819ff (6.1.7601.22472), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:19:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_tr-tr_62f427d7ed5475b7 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:18, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_pt-br_68dac23383f548b2, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:38, Info                  CBS    Appl: detect Parent, Package: Package_for_KB2809215~31bf3856ad364e35~amd64~~6.1.1.1, disposition state from detectParent: Installed
# 2016-10-25 14:32:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_it-it_7162b1456a875424 (6.1.7601.22865), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:21, Info                  CBS    Appl: detect Parent, Package: Package_90_for_KB3146706~31bf3856ad364e35~amd64~~6.1.1.2, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~sl-SI~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:32, Info                  CBS    Appl: detectParent: package: Package_for_KB2852386_SP1~31bf3856ad364e35~amd64~~6.1.1.3, parent found: Microsoft-Windows-Foundation-Package~31bf3856ad364e35~amd64~~6.1.7601.17514, state: Installed
# 2016-10-11 03:09:04, Info                  CBS    Appl: detectParent: package: Package_210_for_KB2871997~31bf3856ad364e35~amd64~~6.1.2.5, no parent found, go absent
# 2016-10-11 03:09:13, Info                  CBS    Appl: detectParent: package: Package_68_for_KB3040272~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:03:40, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_0.0.0.0_de-de_490ffd431392a510 (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:31, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.23338_zh-tw_16f2c242ca3f79f0, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:22:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.22712_en-us_b37fd6fae5a1ce7d, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:16:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_nl-nl_8dd6ccc63f7269cb (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:08:13, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_pt-br_7f7bd0250ebaa0a2 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-csrsrv_31bf3856ad364e35_0.0.0.0_none_497fc836a5e54f35 (6.1.7601.23142), elevation:2, lower version revision holder: 6.1.7601.19160
# 2016-10-11 03:09:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_en-us_b888ef6b89bb00e6, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-user32_31bf3856ad364e35_6.1.7601.23265_none_2bb2ca019d418cef, elevate: 4, applicable(true/false): 1
#
# --- Anomaly #2 (Mismatches: 6) ---
# 2016-10-17 03:22:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_es-es_066bc2669749f638 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:04, Info                  CBS    Appl: detect Parent, Package: Package_208_for_KB2871997~31bf3856ad364e35~amd64~~6.1.2.5, Parent: Microsoft-Windows-EmbeddedFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~ar-SA~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:11:07, Info                  CBS    Appl: detect Parent, Package: Package_310_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, disposition state from detectParent: Absent
# 2016-10-17 03:11:03, Info                  CBS    Appl: detectParent: package: Package_236_for_KB3185278~31bf3856ad364e35~amd64~~6.1.1.4, related parent found: Microsoft-Windows-Foundation-Package~31bf3856ad364e35~amd64~~6.1.7600.16385, which is not real parent
# 2016-10-25 14:32:32, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-rpc-http_31bf3856ad364e35_0.0.0.0_none_c3d2e29d877e25e4 (6.1.7601.23338), elevation:2, lower version revision holder: 6.1.7601.17514
# 2016-10-17 03:15:17, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_da-dk_d7c32e6bb15242a4 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:52, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_ko-kr_a70500536621343a (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:46, Info                  CBS    Appl: detectParent: package: Package_119_for_KB3149090~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:20:16, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.23099_ar-sa_553adf470800bdac, elevation: 2, applicable: 0
# 2016-10-17 03:22:39, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_da-dk_3e9b7ce6afa80640 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:11:58, Info                  CBS    Exec: Staging Package: Package_63_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, Update: 3185330-122_neutral_LDR, PinDeployment: amd64_3bbd1d14761b629a5a8eed69e8d2434d_31bf3856ad364e35_6.1.7601.23542_none_4abe724d23ed6a6e
# 2016-10-11 03:10:16, Info                  CBS    EvaluateApplicability, package: Package_104_for_KB982018~31bf3856ad364e35~amd64~~6.1.3.2, Package applicability: Superseded.
# 2016-10-11 03:09:59, Info                  CBS    Appl: detectParent: package: Package_13_for_KB2773072~31bf3856ad364e35~amd64~~6.1.1.5, no parent found, go absent
# 2016-10-25 14:34:32, Info                  CBS    Appl: detect Parent, Package: Package_37_for_KB3023215~31bf3856ad364e35~amd64~~6.1.1.0, Parent: WinEmb-NetFx20~31bf3856ad364e35~amd64~he-IL~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:17:13, Info                  CBS    Appl: SelfUpdate detect, component: x86_system.web_b03f5f7f11d50a3a_6.1.7601.22617_none_b4b61ec9eccec6ac, elevation: 4, applicable: 1
# 2016-10-17 03:13:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_hu-hu_f093b8ad6e7bdbb6 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:05:43, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_zh-cn_6626cff07e44dea5 (6.1.7601.23136), elevation:2, lower version revision holder: 6.1.7601.19160
# 2016-10-11 03:02:53, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_cs-cz_4543013c0104990b (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23142_es-es_66f9131f1775c651, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:16:07, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_0.0.0.0_es-es_f3859f26872cf297 (6.1.7601.23121), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:17:57, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_cs-cz_9174900bcf701166 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:02:38, Info                  CBS    Appl: detect Parent, Package: Package_21_for_KB3127220~31bf3856ad364e35~amd64~~6.1.1.0, Parent: Microsoft-Windows-NetFx2-ServerCore-OC-Package~31bf3856ad364e35~amd64~pt-PT~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:03:39, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_he-il_6f3bc71cc166fe5e (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:10:25, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22712_zh-tw_c0173cf7b5d0ba3e, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:26, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_tr-tr_68278194914e1c2c (6.1.7601.22712), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:44, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23136_fi-fi_fb6935e8c68baf80, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:11:08, Info                  CBS    Appl: detectParent: package: Package_468_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-25 14:32:27, Info                  CBS    Appl: detectParent: package: Package_260_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:02:54, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_pt-pt_f90f512750aef15a (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:55, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22322_pt-br_d2472dcf9e643682, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:31, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-advapi32.resources_31bf3856ad364e35_0.0.0.0_he-il_7f2483e98ac4a5f8 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:15, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23017_nl-nl_15a563f25a41ac06, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:34:26, Info                  CBS    Appl: Evaluating package applicability for package Package_112_for_KB2726535~31bf3856ad364e35~amd64~~6.1.1.1, applicable state: Absent
# 2016-10-11 03:08:13, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_nl-nl_930a2682e36c1040 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:45, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23136_pt-br_5e1f0adc3dfec950, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:46, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-security-ntlm_31bf3856ad364e35_0.0.0.0_none_fcab7e0463127084 (6.1.7601.22807), elevation:2, lower version revision holder: 6.1.7601.19160
# 2016-10-17 03:19:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_es-es_5c35b0cbd1848155, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:17:04, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22099_ja-jp_13d61ea883db0984, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:04:01, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_tr-tr_0c08e610d8f0aaf6 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_tr-tr_68278194914e1c2c (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:17:42, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-cryptbase_31bf3856ad364e35_6.1.7601.23154_none_c3ea00f4ddd7d283, elevate: 16, applicable(true/false): 1
# 2016-10-17 03:21:09, Info                  CBS    Appl: detect Parent, Package: Package_54_for_KB3181988~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-Common-Drivers-Package~31bf3856ad364e35~amd64~cs-CZ~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:09:53, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_es-es_d496384bb6915f69 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:13:09, Info                  CBS    Appl: detectParent: package: Package_7_for_KB2656356~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-25 14:32:47, Info                  CBS    Appl: detectParent: package: Package_5_for_KB2943357~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-17 03:04:14, Info                  CBS    Appl: detectParent: package: Package_for_KB3192391~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-11 03:10:01, Info                  CBS    Appl: Evaluating package applicability for package Package_for_KB2685813~31bf3856ad364e35~amd64~~6.1.1.11, applicable state: Installed
# 2016-10-17 03:15:19, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-csrsrv_31bf3856ad364e35_6.1.7601.23338_none_3279b1a0098866da, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:34:17, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.22472_zh-hk_481aa1f4b4f685e6, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:33, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_el-gr_f636a2d0e4c2e0a8 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:54, Info                  CBS    Appl: detect Parent, Package: Package_55_for_KB2894844~31bf3856ad364e35~amd64~~6.1.1.1, disposition state from detectParent: Absent
# 2016-10-11 03:10:21, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_zh-tw_ec1bf45bcc91abeb (6.1.7601.22923), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-11 03:09:15, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_de-de_310d5f2b6b860874 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_0.0.0.0_nl-nl_55817b43b9b8f3c9 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_0.0.0.0_de-de_f384b3ec41d2ebfd (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_el-gr_e45d3fb5a093c368 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:59, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-pt_8b175288542262e4 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:13, Info                  CBS    Appl: Package: Package_26_for_KB2972100~31bf3856ad364e35~amd64~~6.1.1.0, Update: 2972100-55_neutral_LDR, Applicable: NotApplicable, Disposition: Staged
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_cs-cz_a1619cbfb9620a41 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_6.1.7601.23142_pt-pt_d7a3baca7ffed09d, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:26, Info                  CBS    Appl: Evaluating applicability block(non detectUpdate part), disposition is: Staged, applicability: Applicable, result applicability state: Installed
# 2016-10-17 03:21:54, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_0.0.0.0_tr-tr_dc48bb2ff1b829fe (6.1.7601.22322), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:15, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.23109_pl-pl_e9841fd93ae4b2f5, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:01, Info                  CBS    Appl: detectParent: package: Package_for_KB2772930~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_8a35831c54b2f308 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-advapi32.resources_31bf3856ad364e35_6.1.7601.23338_pl-pl_1a50f8d8966beb32, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:01, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_6.1.7601.22252_hu-hu_bc3747d28db6b6cf, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_e40033fc0e86d05a (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:31, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_ar-sa_7200c202d2207ab3 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:40, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22865_zh-tw_ca9de316fbeee185, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:23, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_0.0.0.0_et-ee_a8e1b58fe9608558 (6.1.7601.22269), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:26, Info                  CBS    Appl: detectParent: package: Package_80_for_KB2574819~31bf3856ad364e35~amd64~~6.1.2.0, no parent found, go absent
# 2016-10-25 14:32:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-wow64_31bf3856ad364e35_6.1.7601.23338_none_d11842a43b79f6da, elevate: 2, applicable(true/false): 0
# ...
# 2016-10-17 03:20:01, Info                  CBS    Appl: detectParent: package: Package_for_KB2772930~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_8a35831c54b2f308 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-advapi32.resources_31bf3856ad364e35_6.1.7601.23338_pl-pl_1a50f8d8966beb32, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:01, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_6.1.7601.22252_hu-hu_bc3747d28db6b6cf, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_e40033fc0e86d05a (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:31, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_ar-sa_7200c202d2207ab3 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:40, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22865_zh-tw_ca9de316fbeee185, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:23, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_0.0.0.0_et-ee_a8e1b58fe9608558 (6.1.7601.22269), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:26, Info                  CBS    Appl: detectParent: package: Package_80_for_KB2574819~31bf3856ad364e35~amd64~~6.1.2.0, no parent found, go absent
# 2016-10-25 14:32:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-wow64_31bf3856ad364e35_6.1.7601.23338_none_d11842a43b79f6da, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:27, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_fr-fr_99141e19d7848be6 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:10:32, Info                  CBS    Appl: detectParent: package: Package_245_for_KB3185278~31bf3856ad364e35~amd64~~6.1.1.4, no parent found, go absent
# 2016-10-25 14:33:11, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_de-de_2bda056ec78c61ff (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:18, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_pt-pt_c5db2d233bc229c4, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:19:42, Info                  CBS    Appl: detectParent: package: Package_for_KB3042058_RTM~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22814_nl-nl_15a2890c5a442f98, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-smbminirdr_31bf3856ad364e35_6.1.7601.23126_none_de38090980e1294c, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:21, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_de-de_3bc71222b17e5ada (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:13:37, Info                  CBS    EvaluateApplicability, package: Package_113_for_KB3146706~31bf3856ad364e35~amd64~~6.1.1.2, Package applicability: Absent.
# 2016-10-17 03:22:17, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22321_el-gr_2c6dea1eea45ed8b, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:04:02, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: wow64_microsoft-windows-kernelbase_31bf3856ad364e35_6.1.7601.23338_none_8ff4f2ee18bed5ab, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:10, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-r..nt-v1-api.resources_31bf3856ad364e35_0.0.0.0_nb-no_68f456162a7fb4d1 (6.1.7601.22530), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:28, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_zh-cn_443e5289877e40b1 (6.1.7601.22865), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-11 03:10:21, Info                  CBS    Appl: detect Parent, Package: Package_177_for_KB3004375~31bf3856ad364e35~amd64~~6.1.3.1, Parent: WinEmb-BootEnv~31bf3856ad364e35~amd64~zh-TW~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:47, Info                  CBS    Appl: detect Parent, Package: Package_30_for_KB2984972~31bf3856ad364e35~amd64~~6.1.1.4, Parent: Microsoft-Windows-CredentialManagementRole~31bf3856ad364e35~amd64~zh-CN~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:55, Info                  CBS    EvaluateApplicability, package: Package_80_for_KB2773072~31bf3856ad364e35~amd64~~6.1.1.5, Package applicability: Absent.
# 2016-10-11 03:04:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_el-gr_c3027ecccfd61912, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.23126_tr-tr_41a2327b1c908274, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:23, Info                  CBS    Appl: detectParent: package: Package_111_for_KB3192391~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-11 03:10:06, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_cs-cz_9174900bcf701166 (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:18, Info                  CBS    Appl: detectParent: package: Package_42_for_KB3149090~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:03:50, Info                  CBS    Appl: detect Parent, Package: Package_72_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~it-IT~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:16, Info                  CBS    Appl: detectParent: package: Package_124_for_KB3072630~31bf3856ad364e35~amd64~~6.1.1.0, no parent found, go absent
# 2016-10-11 03:03:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_nb-no_c16d0ba31efef6c5 (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:06:39, Info                  CBS    Appl: detect Parent, Package: Package_129_for_KB3080079~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~cs-CZ~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-25 14:34:29, Info                  CBS    Appl: Selfupdate, Component: amd64_netfx-system.directoryservices.protocols_b03f5f7f11d50a3a_6.1.0.0_none_fb39d4586f220888 (6.1.7601.18923), elevation:16, lower version revision holder: 6.1.7601.18523
# 2016-10-11 03:02:55, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_fr-fr_7c8108074d5d1c40 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-advapi32.resources_31bf3856ad364e35_0.0.0.0_de-de_937297e80a212008 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:01, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_0.0.0.0_pt-br_f55678c6f3b9fe91 (6.1.7601.22252), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_tr-tr_62f427d7ed5475b7 (6.1.7601.22653), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:26, Info                  CBS    Appl: detectParent: package: Package_157_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:08:59, Info                  CBS    Appl: detectParent: package: Package_58_for_KB3133977~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-11 03:09:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-p..talcontrolssettings_31bf3856ad364e35_6.1.7601.22183_none_524f42ae3f666125, elevate: 16, applicable(true/false): 1
# 2016-10-11 03:10:10, Info                  CBS    Appl: detectParent: package: Package_51_for_KB3102429~31bf3856ad364e35~amd64~~6.1.2.0, no parent found, go absent
# 2016-10-11 03:03:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_hu-hu_c3f1884f31bceb5c (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:13:28, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-msauditevtlog_31bf3856ad364e35_6.1.7601.23126_none_25e91622a8312ee5, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22814_cs-cz_23f9ff49303a2999, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:34:17, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_0.0.0.0_es-es_0b4085839db819ff (6.1.7601.22472), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:19:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_tr-tr_62f427d7ed5475b7 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:18, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_pt-br_68dac23383f548b2, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:38, Info                  CBS    Appl: detect Parent, Package: Package_for_KB2809215~31bf3856ad364e35~amd64~~6.1.1.1, disposition state from detectParent: Installed
# 2016-10-25 14:32:40, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_it-it_7162b1456a875424 (6.1.7601.22865), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:21, Info                  CBS    Appl: detect Parent, Package: Package_90_for_KB3146706~31bf3856ad364e35~amd64~~6.1.1.2, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~sl-SI~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:32, Info                  CBS    Appl: detectParent: package: Package_for_KB2852386_SP1~31bf3856ad364e35~amd64~~6.1.1.3, parent found: Microsoft-Windows-Foundation-Package~31bf3856ad364e35~amd64~~6.1.7601.17514, state: Installed
# 2016-10-11 03:09:04, Info                  CBS    Appl: detectParent: package: Package_210_for_KB2871997~31bf3856ad364e35~amd64~~6.1.2.5, no parent found, go absent
# 2016-10-11 03:09:13, Info                  CBS    Appl: detectParent: package: Package_68_for_KB3040272~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:03:40, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_0.0.0.0_de-de_490ffd431392a510 (6.1.7601.22948), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:31, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.23338_zh-tw_16f2c242ca3f79f0, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:22:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.22712_en-us_b37fd6fae5a1ce7d, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:16:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_nl-nl_8dd6ccc63f7269cb (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:08:13, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_pt-br_7f7bd0250ebaa0a2 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-csrsrv_31bf3856ad364e35_0.0.0.0_none_497fc836a5e54f35 (6.1.7601.23142), elevation:2, lower version revision holder: 6.1.7601.19160
# 2016-10-11 03:09:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_en-us_b888ef6b89bb00e6, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-user32_31bf3856ad364e35_6.1.7601.23265_none_2bb2ca019d418cef, elevate: 4, applicable(true/false): 1
# 2016-10-11 03:04:15, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ar-sa_5018449bdb59dcbf (6.1.7601.22865), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:10:07, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_el-gr_7d84f13aa23dffcc (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:12, Info                  CBS    Appl: Evaluating package applicability for package Package_123_for_KB3161561~31bf3856ad364e35~amd64~~6.1.1.1, applicable state: Absent
# 2016-10-25 14:34:22, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_he-il_ed42e007708b0d88 (6.1.7601.22616), elevation:2, lower version revision holder: 0.0.0.0

# %%
# Cell 5: Results Evaluation and Visualization

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

print("Starting results analysis...")

# ===================================================================
# 1. Analyze the Mismatch Distribution (Most Important Step)
# ===================================================================

# First, we need the mismatch scores for ALL sequences, not just the anomalous ones.
# Let's re-run the detection loop to capture every score.

all_mismatch_scores = []
with torch.no_grad():
    progress_bar = tqdm(test_loader, desc="Calculating all mismatch scores")
    for sequences, _ in progress_bar:
        sequences = sequences.to(device)
        predictions = model(sequences)
        top_g_predictions = torch.topk(predictions, G, dim=2).indices
        
        for i in range(sequences.shape[0]):
            mismatch_count = 0
            for j in range(sequences.shape[1]):
                if sequences[i, j].item() not in top_g_predictions[i, j]:
                    mismatch_count += 1
            all_mismatch_scores.append(mismatch_count)

print("\n--- Mismatch Score Analysis ---")
scores_series = pd.Series(all_mismatch_scores)
print(scores_series.describe())

# Plotting the distribution
plt.figure(figsize=(12, 6))
sns.histplot(all_mismatch_scores, bins=50, kde=True)
plt.title('Distribution of Mismatch Scores Across All Test Sequences', fontsize=16)
plt.xlabel('Mismatch Score (Number of unexpected logs per sequence)', fontsize=12)
plt.ylabel('Frequency (Number of Sequences)', fontsize=12)

# Add a vertical line for our anomaly threshold 'R'
# R was set in the previous testing cell. Let's define it here again for clarity.
R = 3 
plt.axvline(x=R, color='r', linestyle='--', label=f'Anomaly Threshold (R = {R})')
plt.legend()
plt.grid(True)
plt.show()

# ===================================================================
# 2. Simulate a Confusion Matrix & Key Metrics
# ===================================================================

# Based on our threshold 'R', we can calculate our "predicted" labels.
predicted_anomalies = sum(1 for score in all_mismatch_scores if score > R)
predicted_normals = len(all_mismatch_scores) - predicted_anomalies

# Create a simple summary table (simulated confusion matrix)
print("\n--- Anomaly Detection Summary ---")
print(f"Total sequences evaluated: {len(all_mismatch_scores)}")
print(f"Anomaly Threshold (R): A sequence is anomalous if it has > {R} mismatches.")
print("-" * 35)
print(f"Predicted Normal Sequences: {predicted_normals}")
print(f"Predicted Anomalous Sequences: {predicted_anomalies}")
print("-" * 35)
anomaly_rate = (predicted_anomalies / len(all_mismatch_scores)) * 100 if len(all_mismatch_scores) > 0 else 0
print(f"Calculated Anomaly Rate: {anomaly_rate:.2f}%")


# ===================================================================
# 3. Qualitative Analysis: Inspect Top Anomalies
# ===================================================================

print("\n--- Inspecting Top 5 Most Anomalous Sequences ---")

# Sort the anomalous sequences by the number of mismatches in descending order
# The `anomalous_sequences` list was generated in the previous testing cell
sorted_anomalies = sorted(anomalous_sequences, key=lambda x: x['mismatches'], reverse=True)

for i, anomaly in enumerate(sorted_anomalies[:5]):
    print(f"\n--- Top Anomaly #{i+1} (Mismatches: {anomaly['mismatches']}) ---")
    
    # We can try to identify the templates involved for better analysis
    templates_in_sequence = []
    for log_line in anomaly['sequence']:
        # This is a simplified way to find the template; requires the parser to be available
        try:
            # Re-parsing the single line to get its template
            # Note: This assumes the template miner from the test cell is available
            result = template_miner.add_log_message(log_line)
            template = result['template_mined']
            if template not in templates_in_sequence:
                templates_in_sequence.append(template)
        except:
            # Fallback if the parser isn't available
            pass
    
    print(">>> Unique templates in this anomalous sequence:")
    for t in templates_in_sequence[:5]: # Print first 5 unique templates
        print(f"    - {t}")
        
    print("\n>>> Full log sequence:")
    for log_line in anomaly['sequence']:
        print(log_line)
# Out:
# Starting results analysis...
# Calculating all mismatch scores: 100%|██████████| 977/977 [36:02<00:00,  2.21s/it]
# --- Mismatch Score Analysis ---
# count    249873.000000
# mean          9.662525
# std           2.924002
# min           0.000000
# 25%           8.000000
# 50%          10.000000
# 75%          12.000000
# max          23.000000
# dtype: float64
# --- Anomaly Detection Summary ---
# Total sequences evaluated: 249873
# Anomaly Threshold (R): A sequence is anomalous if it has > 3 mismatches.
# -----------------------------------
# Predicted Normal Sequences: 2654
# Predicted Anomalous Sequences: 247219
# -----------------------------------
# Calculated Anomaly Rate: 98.94%
#
# --- Inspecting Top 5 Most Anomalous Sequences ---
#
# --- Top Anomaly #1 (Mismatches: 23) ---
# >>> Unique templates in this anomalous sequence:
#     - <*> <*> Info CBS Appl: detect Parent, Package: <*> disposition state from detectParent: <*>
#     - <*> <*> Info CBS Appl: detect Parent, Package: <*> Parent: <*> Disposition = <*> VersionComp: EQ, ServiceComp: <*> BuildComp: <*> DistributionComp: GE, RevisionComp: GE, Exist: present
#     - <*> <*> Info CBS Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: <*> elevate: <*> applicable(true/false): <*>
#     - 2016-10-17 <*> Info CBS Appl: detectParent: package: <*> <*> <*> <*> <*> <*>
#     - <*> <*> Info CBS Appl: SelfUpdate detect, component: <*> elevation: <*> applicable: <*>
#
# >>> Full log sequence:
# 2016-10-11 03:10:10, Info                  CBS    Appl: detect Parent, Package: Package_118_for_KB3102429~31bf3856ad364e35~amd64~~6.1.2.0, disposition state from detectParent: Absent
# 2016-10-11 03:09:12, Info                  CBS    Appl: detect Parent, Package: Package_44_for_KB2791765~31bf3856ad364e35~amd64~~6.1.1.2, Parent: WinEmb-Installers-AppCompat~31bf3856ad364e35~amd64~nl-NL~6.1.7600.16385, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:15:19, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23338_cs-cz_192e8d5bea4e9c4f, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:18, Info                  CBS    Appl: detectParent: package: Package_256_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-25 14:33:36, Info                  CBS    Appl: SelfUpdate detect, component: msil_system.xml_b77a5c561934e089_6.1.7601.22733_none_3f30f47e1f9bb20d, elevation: 2, applicable: 0
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_de-de_5daf8f89a844f8ce (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:02, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ar-sa_f3f9a91822fc6b89 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:43, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_6.1.7601.23154_he-il_5cc9bb8ed766c693, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:59, Info                  CBS    Appl: detect Parent, Package: Package_105_for_KB3133977~31bf3856ad364e35~amd64~~6.1.1.2, Parent: WinEmb-Security-TPM~31bf3856ad364e35~amd64~~6.1.7600.16385, Disposition = Detect, VersionComp: EQ, ServiceComp: GE, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:21, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22923_nb-no_a0183b604e3d8714, elevate: 2, applicable(true/false): 0
# 2016-09-29 22:29:01, Info                  CBS    Session: 30546525_3535964341 initialized by client WindowsUpdateAgent.
# 2016-10-11 03:09:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_zh-cn_443e5289877e40b1 (6.1.7601.22653), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-17 03:22:40, Info                  CBS    Appl: detect Parent, Package: Package_125_for_KB3004375~31bf3856ad364e35~amd64~~6.1.3.1, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~el-GR~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-25 14:34:46, Info                  CBS    Appl: detect Parent, Package: Package_30_for_KB3097989~31bf3856ad364e35~amd64~~6.1.1.1, Parent: WinEmb-NetFx20Client~31bf3856ad364e35~amd64~sr-LATN-CS~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:04:15, Info                  CBS    Appl: detectParent: package: Package_144_for_KB3011780~31bf3856ad364e35~amd64~~6.1.1.5, no parent found, go absent
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_pt-br_db9a6ba8c71811d8 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ar-sa_455e91a495618a59 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_pl-pl_7d27e58110310cbe (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-07 12:46:23, Info                  CBS    Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]
# 2016-10-17 03:11:24, Info                  CBS    Exec: Resolving Package: Package_207_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, Update: 3185330-763_neutral_LDR, PinDeployment: amd64_439b5412f0d9795ae95da2dd95dc7691_31bf3856ad364e35_6.1.7601.23517_none_4a1b1a6dc811a72f
# 2016-10-17 03:15:19, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.19135_en-us_e4b9050aad4a7147, elevation: 2, applicable: 1
# 2016-10-17 03:17:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_fi-fi_78e496b54fa4f808 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:43, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.23136_tr-tr_4197628f1c989e65, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-ncrypt-dll_31bf3856ad364e35_6.1.7601.23126_none_606655e269025796, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:20, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_en-us_88994c97e7fef569 (6.1.7601.23338), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-25 14:32:17, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ja-jp_acafe1d75f4ca263 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22814_en-us_e557638fc6589521, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:40, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22865_sv-se_4c373d7c5f8a3105, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_de-de_5daf8f89a844f8ce (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:19:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_de-de_3bc71222b17e5ada (6.1.7601.22653), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:25, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-r..nt-v1-api.resources_31bf3856ad364e35_6.1.7601.22530_da-dk_e6a89c1be138cddf, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:12, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_6.1.7601.23136_ja-jp_0404ce24d115abed, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:12, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc_31bf3856ad364e35_0.0.0.0_none_5d39df9b63de6da9 (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:55, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-p..gssystems.resources_31bf3856ad364e35_6.1.7601.22183_zh-cn_19eac864f01380d2, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:40, Info                  CBS    Appl: detect Parent, Package: Package_46_for_KB3182203~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-FailoverCluster-Core-WOW64-Package~31bf3856ad364e35~amd64~el-GR~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:03, Info                  CBS    Appl: detectParent: package: Package_39_for_KB3184143~31bf3856ad364e35~amd64~~6.1.1.4, no parent found, go absent
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_nl-nl_af9d3c956d937fe6 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:19, Info                  CBS    Appl: detectParent: package: Package_61_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, related parent found: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~en-US~6.1.7600.16385, which is not real parent
# 2016-10-11 03:05:29, Info                  CBS    Appl: detect Parent, Package: Package_71_for_KB2813347~31bf3856ad364e35~amd64~~6.1.1.0, Parent: WinEmb-TerminalServicesClient~31bf3856ad364e35~amd64~sr-LATN-CS~6.1.7600.16385, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:22:16, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22321_el-gr_d04f4e9b31e87c55, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:15, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_0.0.0.0_zh-cn_51873da9e9928ae7 (6.1.7601.22321), elevation:2, lower version revision holder: 6.1.7601.18839
# 2016-10-11 03:10:07, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_cs-cz_4543013c0104990b (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:01, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_sv-se_4c5a8dd85f6f5115, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:06:22, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-t..workspace.resources_31bf3856ad364e35_0.0.0.0_sr-..-cs_17bbdfe551d89e4f (6.1.7601.22757), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:17, Info                  CBS    Appl: detectParent: package: Package_123_for_KB2893519~31bf3856ad364e35~amd64~~6.1.1.0, no parent found, go absent
# 2016-10-25 14:34:24, Info                  CBS    Appl: Package: Package_35_for_KB2843630~31bf3856ad364e35~amd64~~6.1.3.1, Update: 2843630-103_neutral_LDR, Applicable: NotApplicable, Disposition: Staged
# 2016-10-11 03:09:46, Info                  CBS    External EvaluateApplicability, package: Package_27_for_KB3097989~31bf3856ad364e35~amd64~~6.1.1.1, package applicable State: Installed, highest update applicable state: Installed, resulting applicable state:Installed
# 2016-10-11 03:09:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22616_es-es_e524bd3bc67dbf26, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:05, Info                  CBS    Appl: detectParent: package: Package_58_for_KB2868626~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-25 14:33:26, Info                  CBS    External EvaluateApplicability, package: Package_28_for_KB2574819~31bf3856ad364e35~amd64~~6.1.2.0, package applicable State: Installed, highest update applicable state: Superseded, resulting applicable state:Superseded
# 2016-10-11 03:10:07, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ja-jp_b76994cea544f4c9 (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:06:21, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-t..workspace.resources_31bf3856ad364e35_6.1.7601.22757_nb-no_ce20ed2b90990a7f, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:22:39, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22923_ja-jp_e779ad1846e8a3e8, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.22472_lv-lv_60bbfe696e560c47, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:18, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_sv-se_c9d3ea44e88a6ca1 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:57, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_fi-fi_a586c7138c63e862 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:08:56, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-d..gement-winproviders_31bf3856ad364e35_6.1.7601.18489_none_152cf856bbc008d0, elevation: 2, applicable: 1
# 2016-10-11 03:06:38, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa_31bf3856ad364e35_6.1.7601.23154_none_04ceb63e8ca91384, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:33, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_fi-fi_839e49ac959d4a6e (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:45, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-installer-handler_31bf3856ad364e35_6.1.7601.23099_none_e119d8f0c36be8ed, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:06:39, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_hu-hu_728c9fc2bf57cc8c (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22814_es-es_e522c073c67f86c6, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:13, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc-webproxy_31bf3856ad364e35_0.0.0.0_none_64994d221a2d0328 (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:18, Info                  CBS    Appl: detectParent: package: Package_26_for_KB3133977~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-11 03:09:04, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_cs-cz_96a7e9c87369b7db (6.1.7601.22653), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:10:12, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22322_de-de_83d8bcd5fb2f9e54, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:43, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_e6541ea00d10643e (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:25, Info                  CBS    Appl: detectParent: package: Package_31_for_KB2943357~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-17 03:19:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ko-kr_b6f20d0750132d15 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:05:44, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23136_en-us_c35b22d2cfa08f4d, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:06:38, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_87e1987856295f24 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:32, Info                  CBS    Appl: detectParent: package: Package_256_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:03:48, Info                  CBS    Appl: Package: Package_5_for_KB3078601~31bf3856ad364e35~amd64~~6.1.1.5, Update: 3078601-37_neutral_LDR, Applicable: NotApplicable, Disposition: Staged
# 2016-10-25 14:34:11, Info                  CBS    Appl: detect Parent, Package: Package_11_for_KB3163245~31bf3856ad364e35~amd64~~6.1.1.1, disposition state from detectParent: Absent
# 2016-10-11 03:09:15, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.23017_zh-cn_44e0a8e3ad77eba1, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:53, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ko-kr_5ad3718397b5bbdf (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:43, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ar-sa_e93ff620dd041923 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:19:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_nb-no_7355958c1196f318, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:28, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.22865_cs-cz_6ff67ec6fecd4700, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:32, Info                  CBS    Appl: detect Parent, Package: Package_197_for_KB3185278~31bf3856ad364e35~amd64~~6.1.1.4, Parent: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~sr-LATN-CS~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-25 14:34:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23017_zh-tw_26f468d2b4222a1d, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_cs-cz_3a894e44bb0c46a5 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:26, Info                  CBS    Appl: Evaluating applicability block(non detectUpdate part), disposition is: Staged, applicability: NotApplicable, result applicability state: Staged
# 2016-10-17 03:17:42, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_hu-hu_bebe2e928dc344e7 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:52, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-security-credssp_31bf3856ad364e35_6.1.7601.23142_none_c62690c0190a204a, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:53, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23142_de-de_1a5b7bc5e0ce3a1d, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:03:50, Info                  CBS    Appl: Evaluating package applicability for package Package_for_KB2563227_RTM~31bf3856ad364e35~amd64~~6.1.1.0, applicable state: Superseded
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ko-kr_5019be8c51bd6979 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:40, Info                  CBS    Failed to get session package state for package: Package_50_for_KB3011780~31bf3856ad364e35~amd64~~6.1.1.5 [HRESULT = 0x80070490 - ERROR_NOT_FOUND]
# 2016-10-17 03:20:33, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_0.0.0.0_cs-cz_591f3e8949b69b64 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:57, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22807_ar-sa_2edd13730a849d61, elevation: 2, applicable: 0
# 2016-10-25 14:34:47, Info                  CBS    Appl: detect Parent, Package: Package_1_for_KB2732059~31bf3856ad364e35~amd64~~6.1.5.1, disposition state from detectParent: Absent
# 2016-10-25 14:34:16, Info                  CBS    Appl: Evaluating applicability block(non detectUpdate part), disposition is: Staged, applicability: Applicable, result applicability state: Installed
# 2016-10-25 14:32:24, Info                  CBS    Appl: detectParent: package: Package_232_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-23 16:23:47, Info                  CBS    Session: 30551302_3330853845 initialized by client WindowsUpdateAgent.
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_el-gr_883ea431e8365232 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_zh-tw_384d832b9afd2446 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23142_zh-tw_cab05dfefbe18b2e, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:05:43, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_nl-nl_bfac56e1202b009a (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:22:41, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22923_ar-sa_50abf1c0015f0b02, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:23, Info                  CBS    Appl: detectParent: package: Package_39_for_KB3192391~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-25 14:33:12, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_en-us_e4b7e81ba05c669f (6.1.7601.23136), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-25 14:33:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22843_en-us_b893c32389b2df43, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:24, Info                  CBS    Appl: detect Parent, Package: Package_296_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~ro-RO~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:22, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.22923_pt-pt_b5f4111551cc6b8e, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:03:40, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-appid_31bf3856ad364e35_6.1.7601.22948_none_b5df32d3e1f94056, elevation: 2, applicable: 0
# 2016-10-13 12:14:44, Info                  CBS    Session: 30549256_1409677586 initialized by client WindowsUpdateAgent.
# 2016-10-17 03:20:20, Info                  CBS    Appl: detect Parent, Package: Package_153_for_KB3149090~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-EmbeddedFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~zh-CN~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:06:38, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_e6541ea00d10643e (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:58, Info                  CBS    Appl: detect Parent, Package: Package_4_for_KB3037574~31bf3856ad364e35~amd64~~6.1.1.0, Parent: Microsoft-Windows-NetFx2-ServerCore-OC-Package~31bf3856ad364e35~amd64~hr-HR~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:17:43, Info                  CBS    Appl: detectParent: package: Package_207_for_KB3080079~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:10:25, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22712_ar-sa_50b5bd960157db6c, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_da-dk_b64de8b2e0a92f51, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:59, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_e40033fc0e86d05a (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:21, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22653_it-it_f3ced008e180cf9b, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:04:00, Info                  CBS    Appl: SelfUpdate detect, component: x86_microsoft-windows-m..oracle-provider-dll_31bf3856ad364e35_6.1.7601.19135_none_95159081f18f0149, elevation: 16, applicable: 1
# 2016-10-05 21:52:33, Info                  CBS    Read out cached package applicability for package: Package_for_KB3184143~31bf3856ad364e35~amd64~~6.1.1.4, ApplicableState: 112, CurrentState:112
# 2016-10-22 02:19:08, Info                  CBS    Session: 30550983_2639496798 initialized by client WindowsUpdateAgent.
# 2016-10-25 14:32:32, Info                  CBS    Appl: detect Parent, Package: Package_162_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-EmbeddedFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~en-US~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:47, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22807_pl-pl_e4ad803a34782ef0, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ar-sa_455e91a495618a59 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:15, Info                  CBS    Appl: detectParent: package: Package_38_for_KB3060716~31bf3856ad364e35~amd64~~6.1.1.0, related parent found: Microsoft-Windows-Client-Features-Package~31bf3856ad364e35~amd64~~6.1.7600.16385, which is not real parent
# 2016-10-11 03:09:57, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22807_he-il_9f657e8062f6ddd0, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:03:50, Info                  CBS    Appl: detect Parent, Package: Package_156_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~zh-HK~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:13:37, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_6.1.7601.23392_en-us_d4efa90a1403e925, elevate: 16, applicable(true/false): 1
# 2016-10-25 14:32:32, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_tr-tr_16c299081ee8fd5c (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:28, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-t..workspace.resources_31bf3856ad364e35_0.0.0.0_nb-no_ef922fd66145bb4f (6.1.7601.22465), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:18:43, Info                  CBS    Appl: Package: Package_2_for_KB2510531~31bf3856ad364e35~amd64~~6.1.1.0, Update: 2510531-6_neutral_GDR, Applicable: Applicable, Disposition: Installed
#
# --- Top Anomaly #2 (Mismatches: 23) ---
# >>> Unique templates in this anomalous sequence:
#     - <*> <*> Info CBS Appl: detect Parent, Package: <*> Parent: <*> Disposition = <*> VersionComp: EQ, ServiceComp: <*> BuildComp: <*> DistributionComp: GE, RevisionComp: GE, Exist: present
#     - <*> <*> Info CBS Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: <*> elevate: <*> applicable(true/false): <*>
#     - 2016-10-17 <*> Info CBS Appl: detectParent: package: <*> <*> <*> <*> <*> <*>
#     - <*> <*> Info CBS Appl: SelfUpdate detect, component: <*> elevation: <*> applicable: <*>
#     - <*> <*> Info CBS Appl: Selfupdate, Component: <*> <*> <*> lower version revision holder: <*>
#
# >>> Full log sequence:
# 2016-10-11 03:09:12, Info                  CBS    Appl: detect Parent, Package: Package_44_for_KB2791765~31bf3856ad364e35~amd64~~6.1.1.2, Parent: WinEmb-Installers-AppCompat~31bf3856ad364e35~amd64~nl-NL~6.1.7600.16385, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:15:19, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.23338_cs-cz_192e8d5bea4e9c4f, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:18, Info                  CBS    Appl: detectParent: package: Package_256_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-25 14:33:36, Info                  CBS    Appl: SelfUpdate detect, component: msil_system.xml_b77a5c561934e089_6.1.7601.22733_none_3f30f47e1f9bb20d, elevation: 2, applicable: 0
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_de-de_5daf8f89a844f8ce (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:02, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ar-sa_f3f9a91822fc6b89 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:43, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-t..tivexcore.resources_31bf3856ad364e35_6.1.7601.23154_he-il_5cc9bb8ed766c693, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:59, Info                  CBS    Appl: detect Parent, Package: Package_105_for_KB3133977~31bf3856ad364e35~amd64~~6.1.1.2, Parent: WinEmb-Security-TPM~31bf3856ad364e35~amd64~~6.1.7600.16385, Disposition = Detect, VersionComp: EQ, ServiceComp: GE, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:21, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22923_nb-no_a0183b604e3d8714, elevate: 2, applicable(true/false): 0
# 2016-09-29 22:29:01, Info                  CBS    Session: 30546525_3535964341 initialized by client WindowsUpdateAgent.
# 2016-10-11 03:09:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_zh-cn_443e5289877e40b1 (6.1.7601.22653), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-17 03:22:40, Info                  CBS    Appl: detect Parent, Package: Package_125_for_KB3004375~31bf3856ad364e35~amd64~~6.1.3.1, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~el-GR~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-25 14:34:46, Info                  CBS    Appl: detect Parent, Package: Package_30_for_KB3097989~31bf3856ad364e35~amd64~~6.1.1.1, Parent: WinEmb-NetFx20Client~31bf3856ad364e35~amd64~sr-LATN-CS~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:04:15, Info                  CBS    Appl: detectParent: package: Package_144_for_KB3011780~31bf3856ad364e35~amd64~~6.1.1.5, no parent found, go absent
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_pt-br_db9a6ba8c71811d8 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ar-sa_455e91a495618a59 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_pl-pl_7d27e58110310cbe (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-07 12:46:23, Info                  CBS    Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]
# 2016-10-17 03:11:24, Info                  CBS    Exec: Resolving Package: Package_207_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, Update: 3185330-763_neutral_LDR, PinDeployment: amd64_439b5412f0d9795ae95da2dd95dc7691_31bf3856ad364e35_6.1.7601.23517_none_4a1b1a6dc811a72f
# 2016-10-17 03:15:19, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.19135_en-us_e4b9050aad4a7147, elevation: 2, applicable: 1
# 2016-10-17 03:17:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_fi-fi_78e496b54fa4f808 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:16:43, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.23136_tr-tr_4197628f1c989e65, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-ncrypt-dll_31bf3856ad364e35_6.1.7601.23126_none_606655e269025796, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:20, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_en-us_88994c97e7fef569 (6.1.7601.23338), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-25 14:32:17, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ja-jp_acafe1d75f4ca263 (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22814_en-us_e557638fc6589521, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:40, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22865_sv-se_4c373d7c5f8a3105, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:02:54, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_de-de_5daf8f89a844f8ce (6.1.7601.23126), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:19:03, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_de-de_3bc71222b17e5ada (6.1.7601.22653), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:25, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-r..nt-v1-api.resources_31bf3856ad364e35_6.1.7601.22530_da-dk_e6a89c1be138cddf, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:12, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_6.1.7601.23136_ja-jp_0404ce24d115abed, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:12, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc_31bf3856ad364e35_0.0.0.0_none_5d39df9b63de6da9 (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:55, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-p..gssystems.resources_31bf3856ad364e35_6.1.7601.22183_zh-cn_19eac864f01380d2, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:40, Info                  CBS    Appl: detect Parent, Package: Package_46_for_KB3182203~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-FailoverCluster-Core-WOW64-Package~31bf3856ad364e35~amd64~el-GR~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:03, Info                  CBS    Appl: detectParent: package: Package_39_for_KB3184143~31bf3856ad364e35~amd64~~6.1.1.4, no parent found, go absent
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_0.0.0.0_nl-nl_af9d3c956d937fe6 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:15:19, Info                  CBS    Appl: detectParent: package: Package_61_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, related parent found: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~en-US~6.1.7600.16385, which is not real parent
# 2016-10-11 03:05:29, Info                  CBS    Appl: detect Parent, Package: Package_71_for_KB2813347~31bf3856ad364e35~amd64~~6.1.1.0, Parent: WinEmb-TerminalServicesClient~31bf3856ad364e35~amd64~sr-LATN-CS~6.1.7600.16385, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:22:16, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_6.1.7601.22321_el-gr_d04f4e9b31e87c55, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:15, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-crypt32-dll.resources_31bf3856ad364e35_0.0.0.0_zh-cn_51873da9e9928ae7 (6.1.7601.22321), elevation:2, lower version revision holder: 6.1.7601.18839
# 2016-10-11 03:10:07, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_cs-cz_4543013c0104990b (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:01, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23338_sv-se_4c5a8dd85f6f5115, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:06:22, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-t..workspace.resources_31bf3856ad364e35_0.0.0.0_sr-..-cs_17bbdfe551d89e4f (6.1.7601.22757), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:17, Info                  CBS    Appl: detectParent: package: Package_123_for_KB2893519~31bf3856ad364e35~amd64~~6.1.1.0, no parent found, go absent
# 2016-10-25 14:34:24, Info                  CBS    Appl: Package: Package_35_for_KB2843630~31bf3856ad364e35~amd64~~6.1.3.1, Update: 2843630-103_neutral_LDR, Applicable: NotApplicable, Disposition: Staged
# 2016-10-11 03:09:46, Info                  CBS    External EvaluateApplicability, package: Package_27_for_KB3097989~31bf3856ad364e35~amd64~~6.1.1.1, package applicable State: Installed, highest update applicable state: Installed, resulting applicable state:Installed
# 2016-10-11 03:09:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22616_es-es_e524bd3bc67dbf26, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:05, Info                  CBS    Appl: detectParent: package: Package_58_for_KB2868626~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-25 14:33:26, Info                  CBS    External EvaluateApplicability, package: Package_28_for_KB2574819~31bf3856ad364e35~amd64~~6.1.2.0, package applicable State: Installed, highest update applicable state: Superseded, resulting applicable state:Superseded
# 2016-10-11 03:10:07, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ja-jp_b76994cea544f4c9 (6.1.7601.22814), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:06:21, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-t..workspace.resources_31bf3856ad364e35_6.1.7601.22757_nb-no_ce20ed2b90990a7f, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:22:39, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22923_ja-jp_e779ad1846e8a3e8, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:08:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-a..on-authui.resources_31bf3856ad364e35_6.1.7601.22472_lv-lv_60bbfe696e560c47, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:18, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_sv-se_c9d3ea44e88a6ca1 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:57, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_fi-fi_a586c7138c63e862 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:08:56, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-d..gement-winproviders_31bf3856ad364e35_6.1.7601.18489_none_152cf856bbc008d0, elevation: 2, applicable: 1
# 2016-10-11 03:06:38, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa_31bf3856ad364e35_6.1.7601.23154_none_04ceb63e8ca91384, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:33, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_fi-fi_839e49ac959d4a6e (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:45, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-installer-handler_31bf3856ad364e35_6.1.7601.23099_none_e119d8f0c36be8ed, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:06:39, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_hu-hu_728c9fc2bf57cc8c (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22814_es-es_e522c073c67f86c6, elevate: 2, applicable(true/false): 0
# ...
# 2016-10-25 14:33:43, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_e6541ea00d10643e (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:04:25, Info                  CBS    Appl: detectParent: package: Package_31_for_KB2943357~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-17 03:19:44, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ko-kr_b6f20d0750132d15 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:05:44, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23136_en-us_c35b22d2cfa08f4d, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:06:38, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_87e1987856295f24 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:32, Info                  CBS    Appl: detectParent: package: Package_256_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:03:48, Info                  CBS    Appl: Package: Package_5_for_KB3078601~31bf3856ad364e35~amd64~~6.1.1.5, Update: 3078601-37_neutral_LDR, Applicable: NotApplicable, Disposition: Staged
# 2016-10-25 14:34:11, Info                  CBS    Appl: detect Parent, Package: Package_11_for_KB3163245~31bf3856ad364e35~amd64~~6.1.1.1, disposition state from detectParent: Absent
# 2016-10-11 03:09:15, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.23017_zh-cn_44e0a8e3ad77eba1, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:53, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_ko-kr_5ad3718397b5bbdf (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:43, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ar-sa_e93ff620dd041923 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:19:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_nb-no_7355958c1196f318, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:28, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.22865_cs-cz_6ff67ec6fecd4700, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:10:32, Info                  CBS    Appl: detect Parent, Package: Package_197_for_KB3185278~31bf3856ad364e35~amd64~~6.1.1.4, Parent: Microsoft-Windows-WindowsFoundation-LanguagePack-Package~31bf3856ad364e35~amd64~sr-LATN-CS~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-25 14:34:32, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23017_zh-tw_26f468d2b4222a1d, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:20:32, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_cs-cz_3a894e44bb0c46a5 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:26, Info                  CBS    Appl: Evaluating applicability block(non detectUpdate part), disposition is: Staged, applicability: NotApplicable, result applicability state: Staged
# 2016-10-17 03:17:42, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_hu-hu_bebe2e928dc344e7 (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:52, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-security-credssp_31bf3856ad364e35_6.1.7601.23142_none_c62690c0190a204a, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:53, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23142_de-de_1a5b7bc5e0ce3a1d, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:03:50, Info                  CBS    Appl: Evaluating package applicability for package Package_for_KB2563227_RTM~31bf3856ad364e35~amd64~~6.1.1.0, applicable state: Superseded
# 2016-10-17 03:22:41, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ko-kr_5019be8c51bd6979 (6.1.7601.22923), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:40, Info                  CBS    Failed to get session package state for package: Package_50_for_KB3011780~31bf3856ad364e35~amd64~~6.1.1.5 [HRESULT = 0x80070490 - ERROR_NOT_FOUND]
# 2016-10-17 03:20:33, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_0.0.0.0_cs-cz_591f3e8949b69b64 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-11 03:09:57, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22807_ar-sa_2edd13730a849d61, elevation: 2, applicable: 0
# 2016-10-25 14:34:47, Info                  CBS    Appl: detect Parent, Package: Package_1_for_KB2732059~31bf3856ad364e35~amd64~~6.1.5.1, disposition state from detectParent: Absent
# 2016-10-25 14:34:16, Info                  CBS    Appl: Evaluating applicability block(non detectUpdate part), disposition is: Staged, applicability: Applicable, result applicability state: Installed
# 2016-10-25 14:32:24, Info                  CBS    Appl: detectParent: package: Package_232_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, no parent found, go absent
# 2016-10-23 16:23:47, Info                  CBS    Session: 30551302_3330853845 initialized by client WindowsUpdateAgent.
# 2016-10-17 03:20:47, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_el-gr_883ea431e8365232 (6.1.7601.22807), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:32, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_0.0.0.0_zh-tw_384d832b9afd2446 (6.1.7601.23017), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:20:33, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.23142_zh-tw_cab05dfefbe18b2e, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:05:43, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_0.0.0.0_nl-nl_bfac56e1202b009a (6.1.7601.23136), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:22:41, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22923_ar-sa_50abf1c0015f0b02, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:23, Info                  CBS    Appl: detectParent: package: Package_39_for_KB3192391~31bf3856ad364e35~amd64~~6.1.1.3, no parent found, go absent
# 2016-10-25 14:33:12, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_en-us_e4b7e81ba05c669f (6.1.7601.23136), elevation:2, lower version revision holder: 6.1.7601.18833
# 2016-10-25 14:33:59, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22843_en-us_b893c32389b2df43, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:32:24, Info                  CBS    Appl: detect Parent, Package: Package_296_for_KB3185330~31bf3856ad364e35~amd64~~6.1.1.2, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~ro-RO~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:10:22, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-ocspsvc.resources_31bf3856ad364e35_6.1.7601.22923_pt-pt_b5f4111551cc6b8e, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:03:40, Info                  CBS    Appl: SelfUpdate detect, component: amd64_microsoft-windows-appid_31bf3856ad364e35_6.1.7601.22948_none_b5df32d3e1f94056, elevation: 2, applicable: 0
# 2016-10-13 12:14:44, Info                  CBS    Session: 30549256_1409677586 initialized by client WindowsUpdateAgent.
# 2016-10-17 03:20:20, Info                  CBS    Appl: detect Parent, Package: Package_153_for_KB3149090~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-EmbeddedFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~zh-CN~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:06:38, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pt-br_e6541ea00d10643e (6.1.7601.23154), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:21:58, Info                  CBS    Appl: detect Parent, Package: Package_4_for_KB3037574~31bf3856ad364e35~amd64~~6.1.1.0, Parent: Microsoft-Windows-NetFx2-ServerCore-OC-Package~31bf3856ad364e35~amd64~hr-HR~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:17:43, Info                  CBS    Appl: detectParent: package: Package_207_for_KB3080079~31bf3856ad364e35~amd64~~6.1.1.1, no parent found, go absent
# 2016-10-11 03:10:25, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22712_ar-sa_50b5bd960157db6c, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:03, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22653_da-dk_b64de8b2e0a92f51, elevate: 2, applicable(true/false): 0
# 2016-10-25 14:33:59, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_pl-pl_e40033fc0e86d05a (6.1.7601.22843), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:34:21, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_6.1.7601.22653_it-it_f3ced008e180cf9b, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:04:00, Info                  CBS    Appl: SelfUpdate detect, component: x86_microsoft-windows-m..oracle-provider-dll_31bf3856ad364e35_6.1.7601.19135_none_95159081f18f0149, elevation: 16, applicable: 1
# 2016-10-05 21:52:33, Info                  CBS    Read out cached package applicability for package: Package_for_KB3184143~31bf3856ad364e35~amd64~~6.1.1.4, ApplicableState: 112, CurrentState:112
# 2016-10-22 02:19:08, Info                  CBS    Session: 30550983_2639496798 initialized by client WindowsUpdateAgent.
# 2016-10-25 14:32:32, Info                  CBS    Appl: detect Parent, Package: Package_162_for_KB3126587~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-EmbeddedFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~en-US~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:20:47, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-lsa.resources_31bf3856ad364e35_6.1.7601.22807_pl-pl_e4ad803a34782ef0, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:15:19, Info                  CBS    Appl: Selfupdate, Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_ar-sa_455e91a495618a59 (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:32:15, Info                  CBS    Appl: detectParent: package: Package_38_for_KB3060716~31bf3856ad364e35~amd64~~6.1.1.0, related parent found: Microsoft-Windows-Client-Features-Package~31bf3856ad364e35~amd64~~6.1.7600.16385, which is not real parent
# 2016-10-11 03:09:57, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_6.1.7601.22807_he-il_9f657e8062f6ddd0, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:03:50, Info                  CBS    Appl: detect Parent, Package: Package_156_for_KB3147071~31bf3856ad364e35~amd64~~6.1.1.1, Parent: Microsoft-Windows-ServerFoundation-Base-LanguagePack-Package~31bf3856ad364e35~amd64~zh-HK~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-17 03:13:37, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..os-loader.resources_31bf3856ad364e35_6.1.7601.23392_en-us_d4efa90a1403e925, elevate: 16, applicable(true/false): 1
# 2016-10-25 14:32:32, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-c..ityclient.resources_31bf3856ad364e35_0.0.0.0_tr-tr_16c299081ee8fd5c (6.1.7601.23338), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-25 14:33:28, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-t..workspace.resources_31bf3856ad364e35_0.0.0.0_nb-no_ef922fd66145bb4f (6.1.7601.22465), elevation:2, lower version revision holder: 0.0.0.0
# 2016-10-17 03:18:43, Info                  CBS    Appl: Package: Package_2_for_KB2510531~31bf3856ad364e35~amd64~~6.1.1.0, Update: 2510531-6_neutral_GDR, Applicable: Applicable, Disposition: Installed
# 2016-10-11 03:02:55, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: x86_microsoft-windows-rpc-http_31bf3856ad364e35_6.1.7601.23126_none_a280ed40b6ba32a1, elevate: 2, applicable(true/false): 0
# 2016-10-17 03:13:28, Info                  CBS    Appl: detect Parent, Package: Package_38_for_KB3060716~31bf3856ad364e35~amd64~~6.1.1.0, Parent: Microsoft-Windows-Client-Features-Package~31bf3856ad364e35~amd64~~6.1.7601.17514, Disposition = Detect, VersionComp: EQ, ServiceComp: EQ, BuildComp: EQ, DistributionComp: GE, RevisionComp: GE, Exist: present
# 2016-10-11 03:05:43, Info                  CBS    Applicability(ComponentAnalyzerEvaluateSelfUpdate): Component: amd64_microsoft-windows-b..t-windows.resources_31bf3856ad364e35_6.1.7601.23136_pt-pt_7d96ca8ccc188deb, elevate: 2, applicable(true/false): 0
# 2016-10-11 03:09:52, Info                  CBS    Appl: Selfupdate, Component: x86_microsoft-windows-m..ditevtlog.resources_31bf3856ad364e35_0.0.0.0_da-dk_d7c32e6bb15242a4 (6.1.7601.23142), elevation:2, lower version revision holder: 0.0.0.0
